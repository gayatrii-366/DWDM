# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatrii-366/DWDM/blob/main/carS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/gayatrii-366/DWDM.git"
# Out:
# Cloning into 'DWDM'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
import pandas as pd

url = "/content/DWDM/CAR  (Responses) - Form responses 1.csv"

dataset = pd.read_csv(url)

print("Original Dataset:")
print(dataset.head())

new_dataset = dataset.dropna()

print("\nCleaned Dataset:")
print(new_dataset.head())

replaced_dataset = dataset.fillna(0)

replaced_specific = dataset.fillna({
    'Column1': 0,
    'Column2': 'Unknown'
})

print("\nDataset with NaN values replaced:")
print(replaced_dataset.head())

print("\nDataset with specific replacements for NaN values:")
print(replaced_specific.head())
# Out:
# Original Dataset:
#              Timestamp 1. What is your name?\n   Age group  \
# 0  08/01/2025 15:30:45            Rutav Mehta   ☐ Under 18
# 1  08/01/2025 15:35:09         Gargi Yekhande   ☐ Under 18
# 2  08/01/2025 18:06:42            Pravin Swami     ☐ 45–54
# 3  08/01/2025 18:54:07                 Archu S  ☐ Under 18
# 4  08/01/2025 21:51:07                 Vedant   ☐ Under 18
#
#   Do  you currently own a car ? What type of car do you own or prefer?\n  \
# 0                            No                                      SUV
# 1                            No                                      SUV
# 2                           Yes                                Hatchback
# 3                            No                           Other: _______
# 4                           Yes                           Other: _______
#
#   What brand is your car (or your preferred brand)?  \
# 0                                 Current - Hyundai
# ...
