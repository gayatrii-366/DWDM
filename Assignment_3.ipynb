# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatrii-366/DWDM/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone "https://github.com/gayatrii-366/DWDM.git"
# Out:
# Cloning into 'DWDM'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 13.05 KiB | 13.05 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
import pandas as pd
df = pd.read_csv('/content/DWDM/CAR  (Responses) - Form responses 1.csv')

#print("Original data:")
#df.head()

new_df = df.dropna()
print("New data:")
new_df.head()

df.fillna(0, inplace = True)
print("New data:")
df.head()
# Out:
# New data:
# New data:
#              Timestamp 1. What is your name?\n   Age group  \
# 0  08/01/2025 15:30:45            Rutav Mehta   ☐ Under 18
# 1  08/01/2025 15:35:09         Gargi Yekhande   ☐ Under 18
# 2  08/01/2025 18:06:42            Pravin Swami     ☐ 45–54
# 3  08/01/2025 18:54:07                 Archu S  ☐ Under 18
# 4  08/01/2025 21:51:07                 Vedant   ☐ Under 18
#
#   Do  you currently own a car ? What type of car do you own or prefer?\n  \
# 0                            No                                      SUV
# 1                            No                                      SUV
# 2                           Yes                                Hatchback
# 3                            No                           Other: _______
# 4                           Yes                           Other: _______
#
#   What brand is your car (or your preferred brand)?  \
# 0                                 Current - Hyundai
# ...
